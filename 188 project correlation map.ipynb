# %%
import numpy as np
import scipy as sp
import pandas as pd

from sklearn.model_selection import train_test_split

# Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

d = pd.read_csv('/Users/kevinlazatin/Desktop/all (1)/train_V2.csv')
test1 = pd.read_csv('/Users/kevinlazatin/Desktop/all (1)/test_V2.csv')

# %%
#correlation map code taken from titanic example on canvas
def plot_correlation_map( df ):
    corr = pubg.corr()
    _ , ax = plt.subplots( figsize =( 40 , 40 ) ) #12 10
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    _ = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 16 }
    )

# %%
train = d
test = test1
full = train.append( test , ignore_index = True )
pubg = full #[ :891 ]

del train , test

print ('Datasets:' , 'full:' , full.shape , 'pubg:' , pubg.shape)
# Out:
# /Users/kevinlazatin/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
# Datasets: full: (6381140, 29) pubg: (6381140, 29)

# %%
plot_correlation_map( pubg )
